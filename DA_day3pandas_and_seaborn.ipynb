# %% [markdown]
# #pandas:
# *it is  also like to be as a sets consists of rows and coloums
#
# *pandas consists of rows and coloums in a tabular form
#
# *used for data maniplaction (data cleaning,orginzing data)
#
# *go to kaggle website  and go to datasets within datasets dowload -(text files,excel files,csv files)
#
# *create data frames from excel ,csv,tx,dbs
#
# *dataframes(rows and coloums readable by python)
#
# *data cleanin by droping or replacing with mean
#
# *visual the data

# %%
import pandas as pd #pandas=tabular form

# %%
import pandas as pd
names=["pavani","sweety","kanteti"]
index=[40,42,45]
ser1=pd.Series(names,index)#series as a keyword
print(ser1)
# Out:
# 40     pavani
# 42     sweety
# 45    kanteti
# dtype: object

# %% [markdown]
# #importing files
# *  for csv and txt : read_csv
# *  for excel:read_excel

# %%
df=pd.read_csv("/content/diabetcsv.csv")#diabetcsv.csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-664acc826526> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/content/diabetcsv.csv")#diabetcsv.csv
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(10)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4add252522c8> in <cell line: 1>()
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
dft=pd.read_csv("/content/grades.txt",sep= " ")#grades.txt

# %%
dft.head(10)#sem=nan->no a number(abstance)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+
# 5     Raj        M   8.9   9.1   9.3     A
# 6  Hassan        V   9.9   9.0   9.2     A
# 7    Mari        N   7.7   8.0   7.1     B
# 8    Jess        K   9.8   9.1   9.9    A+
# 9  Rajini        M   7.0   9.1   9.3     A

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")#diabets.xlsx

# %%
dfe.head(10)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
print(dft.describe)#use dft
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B>

# %%
print(dft.shape)
# Out:
# (16, 6)

# %%
print(dft.shape[0])
# Out:
# 16

# %%
print(dft.shape[1])
# Out:
# 6

# %% [markdown]
# #Accessing data
# loc-accept coloums names and index
#
# iloc-accept only index

# %%
print(dft.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade'], dtype='object')

# %%
print(dft[2:5])#to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5,"Names"])
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5])#row of specific coloum
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.iloc[2:5,:3])#iloc[row range,coloum range]>=index
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum()#to view how many nulls we have per coloum
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum()#to view total null
# Out:
# 4

# %%
dfc=dfn.dropna()#drop nullsing all the rows with

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# #cleaning with mean

# %%
m=dfn["SEM3"].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
print(dfc2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=dfc2.drop_duplicates()
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# #columns

# %%
dfc2.rename(columns={"Grade":"Gpa"}) #df.rename(columns={old:new})
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Gpa  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 3     Mary        N   7.7   8.0   9.1   B       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 8     Jess        K   9.1   9.1   9.9  A+       1
# 9   Rajini        M   9.1   9.1   9.3   A       0
# 10   Kiran        V   9.1   9.3   9.2   A       0
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
dfc2.rename(columns={"Grade":"Gpa"},inplace=True)

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Gpa  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   9.1   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
dfc2["Avg_score"]=(dfc2["SEM1"]+dfc2["SEM2"]+dfc2["SEM3"])/3

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Gpa  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0   A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1   B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9  A+       1   9.600000

# %%
dfc2[["SEM1","SEM2"]].plot.line()
# Out:
# <Axes: >

# %%
dfc2[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# #seaborn=making statical graphs in python
# 1.pandas(sets)-access tables,graphs.
#
# 2.seaborn(graphs)-access graphs,bargraphs.

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=dfc2)

# %%
pl=sns.barplot(x='Names',y='SEM1',data=dfc2)

# %%
sns.relplot(data=dfc2,x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# * load diabets as csv
# *create replot with
# *age in the x axis and class as coloums

# %%
dfc4=pd.read_csv("/content/diabetcsv.csv")

# %%
dfc4.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
dfc4["index"]=(range(1,769))

# %%
dfc4
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
sns.relplot(data=dfc4,x="index",y="age",col="class")

# %% [markdown]
#  #seaborn
#
#  *seinblit data sets in seaborn
#
#  -tips
#
#  -dowjones
#
#  -fmri
#
#  -dots
#
#  -healthexp
#
#  *to load data set=load_dataset("dataset name")

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
healthexp=sns.load_dataset("healthexp")
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
import seaborn as sns

# %%
sns.relplot(data=tips,x="total_bill",y="tip")

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time",style="smoker",palette="deep")

# %%
sns.relplot(data=tips,x="total_bill",y="time",kind="violin")

# %% [markdown]
# hue=diff color
#
# pastel color
#
# bright
#
# dark
# muted
# colour blind
# palette

# %%
sns.lineplot(data=tips,x="total_bill",y="tip",hue="time",style="time",palette="bright")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=dowjones,x="Date",y="Price")

# %%
sns.relplot(data=dowjones,x="Date",y="Price",kind="line")

# %%
sns.relplot(data=fmri,x="timepoint",y="signal")

# %% [markdown]
# type pointers =no.of sec
# region=brain loc
# signal

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time",style="smoker",palette="deep")

# %%
sns.catplot(data=tips,x="total_bill",y="time")

# %%
sns.catplot(data=tips,x="time",y="total_bill")

# %%
sns.catplot(data=tips,x="total_bill",y="time",kind="violin")

# %%
sns.catplot(data=tips,x="total_bill",y="time",kind="violin",hue="smoker")

# %%
sns.catplot(data=tips,x="total_bill",y="day",kind="violin",hue="smoker")

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %%
sns.lmplot(data=tips,x="tip",y="size")

# %% [markdown]
# ta

# %% [markdown]
# e da

# %% [markdown]
# #webscrapping
# webscrapping=loading the data from the website
# 4.1-
# *loading data from website
# *unstructured in HTML
# *convertiable into spreadsheets/DB
# *major websites have their
# #scrapper
# extract all the dat on particular sites
# *specific data that a user wants
# process:
# URL->
# HTML code->
# Elements(CSS/JS)->
# scraped the required data->
# saves it in required format(csv,xlsx,json)
#
# ---
