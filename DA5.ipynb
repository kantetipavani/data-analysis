# %% [markdown]
# #API-converting a program into a tabular form
#
# extracting data from coinmarket cap API
#
# program flow:
#
# 1.go to coinmarket cap website
#
# 2.go to very bottom products and click crypoto API products-->API and optain API key
#
# *then it will show you 2 options assess 1 "option as Get your API key now",then sign up with your details.
#
# *then it will show you API keys-COPY THE API KEYS *****.and at athe left do to API  documentation
#
# 3.go to documentation to obtain API code!
#
# 4.know your python code!
#
# 5.run it in any python environment
#
# 6.obtain data in the form of json
#
# 7.normalize the data into dta frame
#
# 8.save it if you need

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/105.jpg","link":"https:\/\/randomfox.ca\/?i=105"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/105.jpg', 'link': 'https://randomfox.ca/?i=105'}

# %%
#login to coinmarketcap and access the coad.
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '7540626c-868e-442a-8323-7aa024d20f58',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T15:32:39.448Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5099, 'name': '4vc0brzk8lp', 'symbol': '6y4nxnsvm8b', 'slug': '5m8bg46o3lw', 'cmc_rank': 803, 'num_market_pairs': 8756, 'circulating_supply': 9506, 'total_supply': 7466, 'max_supply': 2943, 'infinite_supply': None, 'last_updated': '2024-02-16T15:32:39.447Z', 'date_added': '2024-02-16T15:32:39.447Z', 'tags': ['9brtcmj2i3', 'd8g17xs0div', '8rznvl82p6g', 'a656u1qyelm', '0678cuns0j49', '6jj760bmr0x', 'zuwqisy8i4', 'r5viegisog', 'ada5j27doi', 'j11by7nqy1'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.728070074951342, 'volume_24h': 770, 'volume_change_24h': 0.8905387270116079, 'percent_change_1h': 0.8126851470548115, 'percent_change_24h': 0.7930586305219613, 'percent_change_7d': 0.9419250386567044, 'market_cap': 0.6323937902935641, 'market_cap_dominance': 
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  5099  4vc0brzk8lp  6y4nxnsvm8b  5m8bg46o3lw       803              8756
# 1  3601  4flpz0nsafu  4m3921f7fon  3d4jhgx9pkk      9917              3029
# 2  4587  nexout19m2m   8j3s39zlfu   msjogkir0s      3169              5640
# 3  6121  se92cdu0moh  1g2hl2en713   x4t1e2en2x      8545              8596
# 4  3204   k9fdnpsqg5  hqcz98lii5f   plinh7gje3      2410              5498
# 5  4770  d2xpmvx03sb  ccaq4pvnw07  irotdx0vxpb       727              2659
# 6  5616  9i9oxm4xiob  1dvn2al35ta  abno2bvtnz4      2834              8719
# 7  9507   ydwny9d1jt  hsjnlkeuvlc  yxyevnmhgfs      1059              4194
# 8  6367  dx1lhy2w53m  n8e6wpoh0oo   tdivw8ybxa      5092              2915
# 9   171   k105h10jna  yxbbcah1we8  s8wme15pnc7       903              9253
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                9506          7466        2943            None  ...
# ...

# %% [markdown]
# #machine learning
#
# *supervised learning-telling the system the feature of the picture.
#
# 1.trians with label and output is any one of these label.
#
# 2.take a feature for every label
#
# 3.output is any one of these label
#
# *when you provide a new coin to a mechainit will look for the feature value then it check for it feature values with labels then it will provide
# that label as a output
#
# Algorithm:
#
# 1.linear regresioto
# 2.logistic regresion
# 3.decision tree
# 4.random forest etc..
